# %% [markdown]
# <a href="https://colab.research.google.com/github/davidchois/Aplicadas-1/blob/main/Gonzalez_David_A00410841.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Biografia**
# Mi nombre completo es **David Gonzalez Chois**,tengo 17 años y actualmente estoy cursando segundo semestre de mi carrera.Estudio Ingernieria en energia,una carrera reciente creada por la universidad Icesi en compañia con empresas del sectro energetico como Celsia.
# <br>
# En cuanto a mis gustos y aficinoes puedeo decir que los autos ocupan un lugar esencial ,es un tema recurrente de conversacion con mis amigos,asi como los deportes ,especialemnte el football.Naci en Cali,vivo en una casa familiar juntos con mis abuelos maternos,me gruadue del colegio Claret hace  mas de 8 meses.Mi pelicula favorita es Interstellar.<centrar>

# %% [markdown]
# # **Foto:**

# %% [markdown]
# ![Foto1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Canciones:
#  > <font color ="red"> *Amor y Control* </font> – Rubén Blades *(compuesta por el mismo Rubén Blades)*.
#
# >> <font color ="green"> *Inocente* </font>   – Romeo Santos *(compuesta por Romeo Santos junto a otros colaboradores)*.
#
# >>> <font color ="blue"> *Desde mis ojos* </font> – Jhay Wheeler *(compuesta por Jhay Wheeler, Botlok, Dirty y Yeziell Yeziell)*.
#
# >>>> <font color ="green" > *Lo Dudo* </font>– José José *(compuesta por Manuel Alejandro)*.
#
# >>>>>  <font color ="blue"> *Ibiza* </font> – Ozuna *(compuesta por Juan Carlos Ozuna Rosado, Anthony Santos, Joseph Alexis Negrón Vélez, José Antonio Aponte, Carlos Enrique Ortiz Rivera y Vicente Saavedra)*

# %% [markdown]
# |<font color ="red"> **Materia**  </font>| <font color ="red"> **Razones** </font> |
# |----------|-----------|
# |  Energia Global ll       |  Es la materia de nucleo de mi carrera.<br>La imparte el director de la misma,<br>es interesante la realcion y el crecimiento<br>de las energia renovables sobre las fromas<br> tradicionales de producir energia.   |
# |         APO l  | Es el curso introductorio de Java,es un lenguaje<br> de programcion con el que no estoy muy relacionado<br> pero me parece interesante,aunque sea tedioso.     |
# |  Principios de Economia|   Aunque sea un materia de nucleo comun<br>,me inclino a pensar que puede llegar a ser<br> util al momento de tomar desciciones financieras<br> en un futuro. |

# %% [markdown]
# $x^2 $
# $$x^2$$
# $$ a/b$$
#
# $c^2 =a^2 +b^2$
#
# $$\frac{-b\pm\sqrt{b^2-4ac}}{2a}$$
# $\sqrt{2}$
#
# $e^{\pi i} + 1=0$
#
# $\pm$

# %% [markdown]
# # 17. Ecuaciones que cambiaron al mundo

# %% [markdown]
# ## *1. Teorema de pitagoras:*
#
#
# ### $$a^2 + b^2 = c^2$$

# %% [markdown]
# ## *2. Logaritmos:*
#
#  ### $$log(xy) = log(x) + log(y)$$

# %% [markdown]
# ## *3. Calculo:*
#
#
#  ### $$ \frac{d}{dx} = \lim_{h\to 0} \frac{f(x+h)-f(x)}{h} $$

# %% [markdown]
# ## *4. Ley de gravitacion:*
#
#
#
# ### $$ F = G \frac{m_1 m_2}{r^2}$$

# %% [markdown]
# ## 5. *Raiz de -1:*
#
# ###  $$ i^2 =-1 $$

# %% [markdown]
# ## *6. Fórmula de Euler para poliedros:*
# ### $$ V-E+F=2$$

# %% [markdown]
# ## *7. Distribución normal:*
#
# ### $$ Φ(x)= \frac{1}{\sqrt{2π}}e^\frac{(x-\mu)^2}{2p^2} $$

# %% [markdown]
# ## *8. Ecuación de onda:*
#
# ### $$\frac{∂^ 2u}{∂t^22} = c^2 \frac{∂^ 2u}{∂x^2} $$

# %% [markdown]
# ## 9. *Transformada de Fourier:*
#
# ### $$ f( \omega )=\int_{\infty}^{\infty} f(x)e^{-2πi.x\omega}dx $$

# %% [markdown]
# ## *10. Ecuación de Navier-Stokes:*
#
# ### $$ \rho(\frac{∂\textbf{v}}{∂t}+ \textbf{v}.\bigtriangledown \textbf{v} ) = - \bigtriangledown p + \bigtriangledown + \textbf{T } +\textbf{f} $$

# %% [markdown]
# ## *11. Ecuaciones de maxwell:*
#
#  ### $$ ∇ ⋅ E = \frac{ρ}{𝞊_0} $$
#
#  ### $$ ∇ ⋅ B = 0 $$
#
#  ### $$ ∇ ⋅ E = -\frac{∂B}{∂t} $$
#
#  ### $$ ∇ ⋅ B = μ_0J + μ_0 𝞊_0 \frac{∂E}{∂t}  $$

# %% [markdown]
# ## *12. Segunda ley de la Termodinamica:*
#
# ### $$ dS\geq0 $$

# %% [markdown]
# ## *13. Relativa de Einstein:*
#
# ### $$ E=mc^2  $$

# %% [markdown]
# ## *14. Ecuacion de Schrödinger:*
# ### $$ ih \frac{∂}{∂t}Ψ= \textbf{H}Ψ $$

# %% [markdown]
# ## *15. Teoria de información (Shannon):*
#
#
#  ### $$  H = -∑p(x) ⋅ log p(x) $$

# %% [markdown]
# ## *16. Teoria del Caos (Ecuación de Lorenz):*
#
#  ### $$ x_{n+1} = rx_n(1-x_n) $$

# %% [markdown]
# ## *17. Ecuacion de Black-Scholes:*
#
#  ### $$ \frac{1}{2} σ^2S^2\frac{∂^2V}{∂S^2}+rS\frac{∂V}{∂S}+\frac{∂V}{∂t} = 0 $$

# %%
num1=int(input("Ingrese numero"))
num2=int(input("Ingrese numero"))
operacion=int(input("Escribe que tipo de operacion deseas hacer 1/suma,2/resta,3/multiplicacion,4/divisio"))
if operacion==1:
    print("El resultado de la operacion es" ,num1+num2)
elif operacion==2:
    print("El resultado de la operacion es" ,num1-num2)
elif operacion==3:
    print("El resultado de la operacion es" ,num1*num2)
elif operacion==4:
    print("El resultado de la operacion es" ,num1/num2)
# Out:
# Ingrese numero3
# Ingrese numero4
# Escribe que tipo de operacion deseas hhacer 1/suma,2/resta,3/multiplicacion,4/divisio2
# El resultado de la operacion es -1
